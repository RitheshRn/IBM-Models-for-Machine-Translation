# %%
from tqdm import tqdm

# %%
# Read english sentences
with open('corpus.en', 'r') as f:
    english_corpus = f.readlines()
    english_corpus = [i[:-1] for i in english_corpus]
    english_corpus = [i.split(' ') for i in english_corpus]
    
# Read Spanish sentences
with open('corpus.es', 'r') as f:
    spanish_corpus = f.readlines()
    spanish_corpus = [i[:-1] for i in spanish_corpus]
    spanish_corpus = [i.split(' ') for i in spanish_corpus]

# %%
# Initialize parameters

# english_vacab
english_vacab = {}
for sent in tqdm(english_corpus):
    for word in sent:
        english_vacab[word] = 0
english_vacab['NULL'] = 0

        
# get the counts n(e)
spanish_vocab = []
for word in tqdm(english_vacab):
    c = []
    for idx in range(len(english_corpus)):
        if word in english_corpus[idx]:
            c += spanish_corpus[idx]
    spanish_vocab += c
    english_vacab[word] = len(set(c))
english_vacab['NULL'] = len(set(spanish_vocab))
spanish_vocab = set(spanish_vocab)

# compute t and cef
cef = {}
for e_word in tqdm(english_vacab):
    temp1 = {}
    for f_word in spanish_vocab:
        temp1[f_word] = 0
    cef[e_word] = temp1
    

# compute ce
ce = {}
for e_word in tqdm(english_vacab):
    ce[e_word] = 0
# Out:
# 100%|██████████| 5401/5401 [00:00<00:00, 227794.06it/s]
# 100%|██████████| 8797/8797 [00:18<00:00, 468.13it/s]
# 100%|██████████| 8797/8797 [00:16<00:00, 548.45it/s]
# 100%|██████████| 8797/8797 [00:00<00:00, 2289624.09it/s]

# %%
import json
with open('t_dump', 'r') as day:
    t = json.load(day)

# %%
for i in range(len(english_corpus)):
    english_corpus[i] = ['NULL'] + english_corpus[i]

# %%
# compute l-(j)-english and m(i)
# q[l][m][(i, j)]

q = {}
c_jilm = {}
c_ilm = {}

for idx in range(len(english_corpus)):

    l = len(english_corpus[idx])
    m = len(spanish_corpus[idx])
    
    
    if l not in q:
        q[l] = dict()
        if m not in q[l]:
            q[l][m] = dict()
    else:
        if m not in q[l]:
            q[l][m] = dict()
        
    if l not in c_jilm:
        c_jilm[l] = dict()
        if m not in c_jilm[l]:
            c_jilm[l][m] = dict()
    else:
        if m not in c_jilm[l]:
            c_jilm[l][m] = dict()
    
    if l not in c_ilm:
        c_ilm[l] = dict()
        if m not in c_ilm[l]:
            c_ilm[l][m] = dict()
    else:
        if m not in c_ilm[l]:
            c_ilm[l][m] = dict()
        
    
    for i in range(m):
        for j in range(l):
            if (i, j) not in q[l][m]:
                q[l][m][(i, j)] = 1/(l+1)
            if (i, j) not in c_jilm[l][m]:
                c_jilm[l][m][(i, j)] = 0 
        if i not in c_ilm[l][m]:
            c_ilm[l][m][i] = 0

# %%
# Initialization for IBM model2

for iteration in tqdm(range(5)):
    
    # set counts to zero
    for q1 in cef:
        for q2 in cef[q1]:
            cef[q1][q2] = 0
            
    for q1 in ce:
        ce[q1] = 0
        
    for ll in c_jilm:
        for mm in c_jilm[ll]:
            for ij in c_jilm[ll][mm]:
                c_jilm[ll][mm][ij] = 0
                
    for ll in c_ilm:
        for mm in c_ilm[ll]:
            for ij in c_ilm[ll][mm]:
                c_ilm[ll][mm][ij] = 0
                
    
    # iterate over corpus
    for k in range(len(english_corpus)):
        m = len(spanish_corpus[k])
        l = len(english_corpus[k])
        for i in range(len(spanish_corpus[k])):
            
            denom = sum([t[english_corpus[k][j]][spanish_corpus[k][i]]*q[l][m][(i, j)] for j in range(len(english_corpus[k]))])
            
            for j in range(len(english_corpus[k])):
                
                # Compute delta
                num = t[english_corpus[k][j]][spanish_corpus[k][i]] * q[l][m][(i, j)]
                delta = num/denom
                
                # Update
                cef[english_corpus[k][j]][spanish_corpus[k][i]] += delta
                ce[english_corpus[k][j]] += delta
                c_jilm[l][m][(i, j)] += delta
                c_ilm[l][m][i] += delta
            
                        
                
    # evelauate t
    for e_word in english_vacab:
        for f_word in spanish_vocab:
            t[e_word][f_word] = cef[e_word][f_word]/ce[e_word]

    for l in q:
        for m in q[l]:
            for ij in q[l][m]:
                q[l][m][ij] = c_jilm[l][m][ij]/c_ilm[l][m][ij[0]]
# Out:
# 100%|██████████| 5/5 [23:24<00:00, 277.93s/it]

# %%
import json
with open('t_model2_dump', 'w') as f:
    json.dump(t, f)

# %%
import json
with open('t_model2_dump', 'r') as day:
    t = json.load(day)

# %%
t['i']
# Out:
# {'': 1.6036001753460843e-155,
#  'someteré': 1.784037285255605e-21,
#  'hatzidakis': 2.169073198850488e-34,
#  'detalle': 1.4529985049858624e-27,
#  'reclamar': 1.2306523079944066e-208,
#  'delegar': 0.0,
#  'naciones': 4.2427401381115735e-29,
#  'nielson': 9.519107074840285e-68,
#  'vascas': 5.51187698629715e-43,
#  'salvados': 0.0,
#  'excusarse': 3.1550358939130784e-190,
#  'terminaré': 2.1456293772507464e-20,
#  'cortapisas': 0.0,
#  'aquellas': 5.492471778994327e-22,
#  'carteles': 9.084328946186162e-30,
#  'liberalizar': 0.0,
#  'sustituidas': 0.0,
#  'surgir': 0.0,
#  'apuntala': 1.8758344995494817e-37,
#  'titulares': 9.285639087528742e-30,
#  'pecio': 0.0,
#  'sancionados': 0.0,
#  'dedicarse': 0.0,
#  'conmocionado': 0.0,
#  'koch': 1.2745822188370715e-31,
#  'balance': 1.6602146770288067e-150,
#  'nutrición': 0.0,
#  'durísimas': 0.0,
#  'finales': 1.4454186153805824e-25,
#  'somete': 3.889461425992208e-24,
#  'situaremos': 0.0,
#  'metros': 0.0,
#  'cordialmente': 7.958755202692645e-26,
#  'parlamentarias': 0.0,
#  'debe': 1.5394493925272787e-12,
#  'desastre': 6.538504783624408e-25,
#  'exportados': 3.753247166312355e-229,
#  'superarse': 0.0,
#  'definen': 4.38696434052879e-29,
#  'yugo': 0.0,
#  'marginados': 0.0,
#  'jordán': 0.0,
#  'mundo': 6.865598694873442e-18,
#  'canalizar': 0.0,
#  'myller': 0.0,
#  'aplaude': 0.0,
#  'comenzaré': 1.0720880195575088e-198,
#  'cabe': 1.9182586940456455e-14,
#  'continuarán': 0.0,
#  'suplemento': 5.026106644335226e-34,
#  'implicados': 0.0,
#  'fatalmente': 0.0,
#  'días': 2.1172450208192486e-65,
#  'descubramos': 0.0,
#  '2000': 7.671807198733444e-24,
#  'lamentablemente': 1.0056479950250017e-34,
#  'anticomunitarios': 0.0,
#  'correctos': 4.66594642609427e-52,
#  'votar': 1.566940895805733e-21,
#  'adopción': 1.7155720124590156e-20,
#  'dónde': 8.403808907642181e-23,
#  'generalización': 0.0,
#  'decisivo': 0.0,
#  'completar': 4.826937255010484e-28,
#  'procesales': 0.0,
#  'sentimos': 8.887274881001581e-42,
#  'caer': 0.0,
#  'recompense': 0.0,
#  'abordadas': 0.0,
#  'aproximación': 1.49913666403258e-27,
#  'efectúe': 9.682550479348523e-28,
#  'diplomacia': 0.0,
#  'iraq': 0.0,
#  'infracciones': 1.3882817724607216e-28,
#  'tomó': 6.504974029372761e-236,
#  'elegibilidad': 0.0,
#  'inmersos': 0.0,
#  'aumentará': 1.1738791307700133e-221,
#  'impidan': 0.0,
#  'vota': 0.0,
#  'lenguaje': 6.013079198066556e-29,
#  'tendríamos': 1.2618388853504838e-37,
#  'europeos': 5.184712171768237e-19,
#  'empeoramiento': 0.0,
#  'indicaciones': 0.0,
#  'reanuda': 0.0,
#  'explosiones': 0.0,
#  'monocultivos': 0.0,
#  'permitido': 8.579546382836212e-85,
#  'cuestiones': 2.49510598931357e-14,
#  'ir': 5.795074401035266e-25,
#  'coordinación': 3.7216376628590344e-35,
#  'cheque': 0.0,
#  'vigor': 2.3945008782222173e-20,
#  '0352': 4.577492376359951e-242,
#  'descripciones': 0.0,
#  'obstruyéndose': 3.1908138316053376e-245,
#  'inefectivo': 0.0,
#  'actuaciones': 2.472630008736387e-28,
#  'masas': 0.0,
#  'determinado': 1.1816909730222615e-63,
#  'congratuló': 0.0,
#  'trabajo': 4.1472086855556073e-16,
#  'descentralizado': 0.0,
#  'ni': 2.722013889415048e-12,
#  'estable': 0.0,
#  'preocupaciones': 3.4339306225421895e-15,
#  'un': 5.602305874041553e-05,
#  'debida': 1.9265076485779069e-22,
#  'celebrar': 1.2606443541097203e-148,
#  'liga': 0.0,
#  'liberación': 0.0,
#  'vertidos': 0.0,
#  'formado': 1.3601739258127836e-29,
#  'sorprendente': 0.0,
#  'llevará': 0.0,
#  'reñida': 0.0,
#  'regiones': 1.2828364228862557e-18,
#  'reducir': 0.0,
#  'invitados': 0.0,
#  'giro': 0.0,
#  'exigido': 0.0,
#  'alguna': 5.684013215130349e-19,
#  'bate': 6.403248227889592e-28,
#  'soplaron': 0.0,
#  'intentos': 0.0,
#  'sacrificios': 0.0,
#  'empleabilidad': 0.0,
#  'gigantescos': 0.0,
#  'ordenación': 0.0,
#  'hacerla': 1.2586913202769708e-27,
#  'precisaba': 0.0,
#  'encima': 6.001519400534117e-24,
#  'marinas': 0.0,
#  'presión': 2.930850978163423e-31,
#  'socorrer': 0.0,
#  'falle': 0.0,
#  'consistir': 0.0,
#  'consideró': 0.0,
#  'prerrogativa': 0.0,
#  'reflexiones': 1.5891063252031774e-26,
#  'senado': 8.112656641702462e-32,
#  '54': 0.0,
#  'norteamericanos': 1.2607980666872008e-52,
#  'errores': 0.0,
#  'jan': 0.0,
#  'adaptar': 0.0,
#  'desarrollada': 4.5984948031176555e-30,
#  'estado': 2.1681410447961532e-14,
#  'diablo': 1.9655428198364048e-32,
#  'idóneo': 0.0,
#  'colaborando': 0.0,
#  'internos': 0.0,
#  'constatado': 0.0,
#  'pesqueras': 9.84607363130132e-30,
#  'abogados': 3.0576694694155446e-38,
#  'atribuidos': 0.0,
#  'reembolso': 0.0,
#  'especialmente': 7.942153120964477e-17,
#  'excusándome': 7.445794601273342e-24,
#  'computan': 0.0,
#  'delegado': 0.0,
#  'mencionaré': 0.0,
#  'ante': 1.1521958760768774e-14,
#  'democrático': 6.668133353612014e-41,
#  '33': 0.0,
#  'mueve': 0.0,
#  'casualidad': 2.1868307339967393e-24,
#  'asia': 2.0746958695152103e-32,
#  'ligeramente': 4.8201448838774124e-27,
#  'opiniones': 4.3006523512010496e-19,
#  'estudiase': 3.200873992465073e-67,
#  'eurodac': 9.935982220996934e-69,
#  'acordarlo': 0.0,
#  'explotaciones': 7.387521814105152e-225,
#  'redactadas': 0.0,
#  'tribunal': 1.30234162113879e-31,
#  '0104': 0.0,
#  'pacífico': 0.0,
#  'directamente': 9.882429357107128e-25,
#  'incluidas': 1.3888863746125653e-176,
#  'culminado': 0.0,
#  'insumos': 0.0,
#  'optó': 0.0,
#  'ahorrado': 0.0,
#  'variedad': 6.484229002928235e-26,
#  'periféricas': 0.0,
#  'decae': 0.0,
#  'escucharé': 6.311291223977097e-28,
#  'cohesión': 5.402439835376767e-25,
#  'seguidos': 0.0,
#  'discrecionalidad': 1.5892001379109037e-221,
#  'considero': 1.897466892714015e-10,
#  'soluciones': 6.01084123645154e-37,
#  'sustraer': 0.0,
#  'proclamado': 0.0,
#  'claude': 0.0,
#  'totalidad': 1.4053700029314246e-24,
#  'obra': 0.0,
#  'incontrolada': 0.0,
#  'hunda': 0.0,
#  'justo': 6.085664166271719e-22,
#  'canadá': 4.891142035839374e-238,
#  'apoyen': 3.446993432281718e-29,
#  'consideraba': 0.0,
#  'registran': 0.0,
#  'alrededor': 0.0,
#  'atendidas': 0.0,
#  'curso': 1.1664313127616294e-20,
#  'básicas': 1.564856947927629e-41,
#  'progresos': 2.3677224937702052e-29,
#  'bellas': 0.0,
#  'failures': 0.0,
#  'leoni': 0.0,
#  'actualmente': 4.807500164712219e-17,
#  'comentan': 0.0,
#  'inagotable': 0.0,
#  'provocaban': 0.0,
#  'aporten': 0.0,
#  'elles': 5.699386159992408e-25,
#  'ultramar': 2.143094108132502e-35,
#  'deseada': 0.0,
#  'obligatorias': 0.0,
#  'refuerzos': 0.0,
#  'pobre': 0.0,
#  'dedique': 3.65213301222091e-22,
#  'espléndido': 4.16607911525289e-27,
#  'oisin': 1.9677181769592487e-241,
#  'empresarios': 4.84273650992549e-37,
#  'parado': 0.0,
#  'estrechas': 0.0,
#  'firmes': 4.555174415327039e-38,
#  '0002': 0.0,
#  'alcanzase': 0.0,
#  'vigente': 1.0008515258274148e-54,
#  'incluye': 2.936513113850565e-24,
#  'vulnerables': 0.0,
#  'valdría': 1.6963624413721844e-58,
#  'utilización': 1.0711640945928423e-21,
#  'seguridad': 7.881434750206167e-19,
#  'permítaseme': 6.265898260519213e-18,
#  'expreso': 1.083485524166694e-18,
#  'auditorio': 0.0,
#  'flexibilidad': 6.987937301102783e-21,
#  'quito': 3.5049446659318434e-25,
#  'trabajen': 0.0,
#  'aseguren': 2.2160631205035188e-29,
#  'apagar': 0.0,
#  'alzada': 1.4185825719305072e-47,
#  'sostenidas': 0.0,
#  'consista': 0.0,
#  'cientos': 0.0,
#  'privatizaciones': 0.0,
#  'indica': 2.4731963459080895e-208,
#  'pequeños': 2.3882378822084922e-257,
#  'ocasionar': 6.065488413289289e-224,
#  '57': 0.0,
#  'ong': 2.5292820523762113e-249,
#  'depositando': 0.0,
#  'suma': 0.0,
#  'epígrafe': 0.0,
#  'quita': 0.0,
#  'determinante': 0.0,
#  'mensaje': 2.5334246712031967e-27,
#  'cometidas': 0.0,
#  'subvierta': 1.2447684827736768e-29,
#  'deben': 1.387914203863425e-14,
#  'formaciones': 0.0,
#  'estudiante': 0.0,
#  'asturias': 8.148493013501147e-61,
#  'ojala': 1.0015176659952144e-189,
#  'quebrará': 4.4105291568898636e-105,
#  'trasvase': 0.0,
#  'sinergias': 0.0,
#  'quedará': 0.0,
#  'competencias': 1.6316790462069527e-25,
#  'detallados': 0.0,
#  'tratará': 0.0,
#  'inviables': 0.0,
#  'ciega': 0.0,
#  'amenazan': 0.0,
#  'desnudas': 0.0,
#  'coordinen': 0.0,
#  'físicas': 0.0,
#  'cristal': 0.0,
#  'inadmisible': 2.1394249449220237e-98,
#  'figuran': 0.0,
#  'absolutas': 0.0,
#  'dejarse': 0.0,
#  'volcán': 0.0,
#  'escribiese': 0.0,
#  'purvis': 0.0,
#  'cocilovo': 2.0498669005377697e-29,
#  'perjudicados': 0.0,
#  'justificada': 1.1773225429104836e-28,
#  'apogeo': 0.0,
#  'plan': 7.808886367410264e-19,
#  'solucionar': 1.3089268526805444e-39,
#  'libertades': 5.127084623829111e-32,
#  'contactos': 0.0,
#  'especializada': 0.0,
#  'hubo': 5.789330452150778e-28,
#  'value': 0.0,
#  'más': 2.7606126092719445e-08,
#  'bce': 0.0,
#  'dejar': 1.9568105908153235e-15,
#  'escape': 0.0,
#  'caídos': 0.0,
#  'interrogado': 0.0,
#  'plantean': 4.661475043322386e-25,
#  'legible': 0.0,
#  'cualesquiera': 0.0,
#  'sufrimiento': 6.060508947342974e-202,
#  'muchísimo': 0.0,
#  'disminuido': 0.0,
#  '20': 9.437728323420835e-24,
#  'concentrar': 1.0872091190140842e-198,
#  'dejemos': 5.6883964780741206e-30,
#  'aumenten': 0.0,
#  'dejen': 0.0,
#  'árabes': 0.0,
#  'llegase': 3.420219179418649e-21,
#  'asuman': 0.0,
#  'marginación': 0.0,
#  'agravará': 0.0,
#  'exhaustivo': 2.4525647717322058e-24,
#  'difícil': 2.3918055053869556e-20,
#  'simplificación': 6.9164486707298816e-161,
#  'auténticos': 6.158166701120815e-212,
#  'dejadas': 0.0,
#  'periódica': 0.0,
#  'tranquilice': 0.0,
#  'volet': 3.2101122866862807e-224,
#  'obtenemos': 0.0,
#  'contribuyente': 0.0,
#  'trata': 3.0503837156095782e-12,
#  'contrariamente': 0.0,
#  'parecería': 8.75610026920821e-211,
#  'imponerse': 0.0,
#  'renuncie': 3.378887960559205e-34,
#  'subyacente': 8.423089275177491e-25,
#  'roth': 1.1009211551345018e-35,
#  'rina': 0.0,
#  'detienen': 0.0,
#  'allí': 3.634316431185734e-23,
#  '0807': 0.0,
#  'anda': 0.0,
#  'completamente': 7.970238448528537e-21,
#  'máquina': 0.0,
#  'filtraciones': 0.0,
#  'repúblicas': 1.1369186297134119e-33,
#  'admiro': 2.547072359280669e-249,
#  '2002': 2.84065804172196e-38,
#  'socialmente': 0.0,
#  'signos': 0.0,
#  'tratamiento': 1.6491948407944295e-29,
#  'incompetencia': 0.0,
#  'enriquecimiento': 2.2692193744726457e-242,
#  'vería': 2.2402753768931683e-233,
#  'fortalezca': 3.400497633163384e-24,
#  'fomentar': 5.155409952444063e-29,
#  'culminante': 0.0,
#  'a': 0.04110661629519358,
#  'hombros': 0.0,
#  'kinnock': 1.9247872070090218e-29,
#  '45': 0.0,
#  'suprima': 2.418371502861015e-30,
#  'compartida': 0.0,
#  '52': 0.0,
#  'franjas': 0.0,
#  'puntualizaciones': 5.337725491245924e-108,
#  'publicadas': 0.0,
#  'encarecidamente': 1.2002243729575365e-28,
#  'examina': 0.0,
#  'injurias': 5.115061029359701e-76,
#  'presidido': 1.0105184848538804e-32,
#  'solicitado': 1.1851622460413758e-24,
#  'discurso': 2.0042524677452897e-22,
#  'reglamentación': 1.5486562002851985e-20,
#  'impacto': 1.1269609421982387e-41,
#  'sospechoso': 0.0,
#  'concesión': 4.934109791884061e-31,
#  'bastaría': 0.0,
#  'consiguientemente': 0.0,
#  'supone': 2.4142684918636406e-21,
#  'atlántico': 1.020780189281987e-35,
#  'consolidar': 0.0,
#  'agricultor': 0.0,
#  'reparaciones': 0.0,
#  'substituido': 0.0,
#  'escenario': 0.0,
#  'rotundas': 0.0,
#  'hacienda': 4.973656206504201e-66,
#  'parecían': 0.0,
#  'solicitemos': 7.611290421975966e-34,
#  'ngo': 0.0,
#  'pudimos': 0.0,
#  'dólares': 0.0,
#  'participado': 1.0408064384023296e-225,
#  'centrar': 6.255790228399662e-28,
#  'ceden': 5.002571101429677e-29,
#  'lujo': 0.0,
#  'severas': 0.0,
#  'profundamente': 6.530236188516532e-19,
#  'radiológica': 5.838317662638569e-34,
#  'navegables': 4.9155933881764625e-40,
#  'especializados': 0.0,
#  'añaden': 0.0,
#  'advertirle': 2.347257453238022e-23,
#  'embargo': 1.8370892802677537e-11,
#  'ampliando': 0.0,
#  'petición': 2.248338039288719e-21,
#  'practicamos': 0.0,
#  'apuntalado': 0.0,
#  'callanan': 0.0,
#  'infracción': 0.0,
#  'caras': 0.0,
#  'severo': 9.507114164422291e-119,
#  'ocupa': 8.175703513964529e-30,
#  'vacas': 8.482539554438975e-35,
#  'modernizar': 0.0,
#  'desarrolle': 1.0263016156355687e-26,
#  'devenir': 0.0,
#  'caracterizan': 0.0,
#  'mutila': 0.0,
#  'impuesto': 1.1578206355584628e-20,
#  'nombre': 7.998397581974512e-19,
#  'dispenso': 7.207915195229914e-115,
#  'plantation': 5.108710600953451e-31,
#  'renunciará': 0.0,
#  'escritora': 0.0,
#  'excelente': 1.055532393101855e-30,
#  '0120': 0.0,
#  'adictos': 3.0938548167068557e-43,
#  'transportara': 0.0,
#  'aplicables': 0.0,
#  'constituidos': 0.0,
#  'alimentarios': 0.0,
#  'bilateral': 0.0,
#  'estructurado': 0.0,
#  'minar': 5.726302804961107e-29,
#  'lógico': 1.4633508337701848e-44,
#  'rogar': 6.533375922849796e-27,
#  'pierde': 0.0,
#  'confirmación': 3.3926563759718715e-233,
#  'concedan': 0.0,
#  'comunidad': 2.264686226839593e-26,
#  'vinculada': 0.0,
#  'económicas': 5.655354922499171e-105,
#  'gastaron': 0.0,
#  'férreas': 2.4506296801796788e-27,
#  'acelerar': 1.4287424493338432e-28,
#  '40': 1.444707926561189e-29,
#  'histórica': 0.0,
#  'aniversario': 0.0,
#  'depósitos': 1.5843256643120575e-33,
#  'falte': 0.0,
#  'resultante': 0.0,
#  'decidió': 2.2057146518347147e-214,
#  'potencia': 0.0,
#  'universal': 2.1450837378304705e-47,
#  'atiene': 0.0,
#  'huelga': 0.0,
#  'expresar': 7.000381392024288e-12,
#  'recesión': 0.0,
#  'abrirá': 0.0,
#  'benelux': 0.0,
#  'remangado': 2.547072359280669e-249,
#  'reaccionado': 0.0,
#  'actual': 2.6017822571929776e-23,
#  'propuso': 0.0,
#  'actúen': 0.0,
#  'justifica': 5.02297390716555e-31,
#  'aborda': 0.0,
#  'acusación': 0.0,
#  'ajustadamente': 1.5892001379109037e-221,
#  'bretón': 1.469260013142764e-87,
#  'llama': 0.0,
#  'want': 0.0,
#  'dinero': 2.9477072975421724e-27,
#  'esperma': 0.0,
#  'depositar': 0.0,
#  'talados': 0.0,
#  'indicamos': 0.0,
#  'aceptada': 0.0,
#  'mínimos': 2.8680285531191233e-28,
#  'garantiza': 1.8279091784884282e-222,
#  'aspiren': 0.0,
#  'mesa': 2.960758804236775e-32,
#  'esperaban': 2.183639868354499e-40,
#  '0780': 0.0,
#  'señalado': 4.0969537366971755e-16,
#  'sucesos': 0.0,
#  'sólida': 0.0,
#  'irreparablemente': 0.0,
#  'produjera': 0.0,
#  'desglosado': 2.0603504147077868e-31,
#  'comprometan': 0.0,
#  'precisa': 1.8018360431721255e-26,
#  'microcréditos': 1.4571857784381264e-29,
#  'distinguido': 0.0,
#  'piramidal': 0.0,
#  'principales': 2.3986180598306865e-22,
#  'adoptó': 1.0357548949446347e-189,
#  'excluye': 0.0,
#  'personas': 2.7404560309774912e-18,
#  'intentando': 1.3369770291421229e-173,
#  'soluciona': 4.184693794669747e-31,
#  'fuertemente': 0.0,
#  'agregados': 0.0,
#  'sentirá': 3.80130786070057e-67,
#  'quién': 7.969114783696113e-20,
#  'transformación': 0.0,
#  'inoportuna': 0.0,
#  'gustaría': 3.48114420896096e-08,
#  'euros': 2.0545845065369582e-29,
#  'madrid': 6.076430635794702e-33,
#  'socioeconómicas': 0.0,
#  'afirmativamente': 5.658042358001752e-26,
#  'católico': 0.0,
#  'juristas': 0.0,
#  'exponerles': 5.6357423088424796e-27,
#  'señoría': 6.15268226428829e-11,
#  'indemnizará': 0.0,
#  'bursátil': 0.0,
#  'ejecutables': 0.0,
#  'concuerdo': 1.6046400846519658e-16,
#  'mucha': 6.127018663585066e-15,
#  'informar': 1.1614851224336452e-22,
#  'dueños': 6.252373321510008e-238,
#  'fórmula': 8.189257246911489e-27,
#  'schulz': 5.9521622127792646e-36,
#  '%,': 5.87565229970451e-25,
#  'lucha': 2.80847099393677e-23,
#  'fijamos': 0.0,
#  'salen': 2.898560429662891e-44,
#  'gama': 5.2065258924731695e-49,
#  'instrumental': 4.66956124689775e-24,
#  'intentar': 5.029394138316618e-25,
#  'particular': 5.990557776166745e-17,
#  '(': 5.923093964768471e-12,
#  'clarificara': 1.8796620373967183e-26,
#  'desestructurar': 0.0,
#  'confidenciales': 0.0,
#  'guerra': 4.5828228703580136e-36,
#  'interesado': 2.9781633138498967e-30,
#  'étnico': 0.0,
#  'requisito': 2.1476292577847266e-38,
#  'completo': 1.0628658190700047e-25,
#  'jai': 9.476352203845306e-222,
#  'aficionado': 0.0,
#  'proporciona': 0.0,
#  'discrepar': 0.0,
#  'grande': 0.0,
#  'reajuste': 3.703317133482428e-29,
#  'examinada': 0.0,
#  'farragosidad': 0.0,
#  'desembocan': 1.244980345240909e-33,
#  'minoría': 0.0,
#  'esconder': 0.0,
#  'vendría': 0.0,
#  'marcan': 0.0,
#  'esquilmar': 0.0,
#  'aves': 0.0,
#  'expensas': 0.0,
#  'prometida': 0.0,
#  'supervivencia': 0.0,
#  'garantizará': 0.0,
#  '**': 0.0,
#  'reclama': 0.0,
#  'pan': 0.0,
#  'podrán': 1.406844948021512e-216,
#  'pesada': 0.0,
#  'deterioradas': 0.0,
#  'información': 4.87978172973051e-19,
#  '180': 0.0,
#  'debilitado': 0.0,
#  'implante': 0.0,
#  'respondo': 6.0032261039513885e-24,
#  'dieron': 7.705888720109693e-27,
#  'sincera': 9.538538906067662e-28,
#  'estimados': 5.221114931498358e-14,
#  'facilita': 2.21476011883798e-162,
#  'tercero': 0.0,
#  'clasificado': 0.0,
#  'implicará': 0.0,
#  'asesinado': 0.0,
#  'potencias': 8.14124361499686e-201,
#  'munich': 2.770014577763579e-209,
#  'corazón': 0.0,
#  'alejamiento': 0.0,
#  'exactamente': 2.2500282591814794e-23,
#  'investidura': 1.1785915052278483e-33,
#  'orientaciones': 3.6602029969913097e-31,
#  'estocolmo': 7.425650777964823e-39,
#  'rehabilitación': 0.0,
#  'encontrarán': 0.0,
#  'eau': 0.0,
#  'logró': 0.0,
#  '119': 0.0,
#  'prisión': 0.0,
#  'tardar': 0.0,
#  'resultará': 0.0,
#  'bretaña': 5.4967795819762476e-33,
#  'comprobaremos': 0.0,
#  'hedkvist': 0.0,
#  'pagarlo': 0.0,
#  'delegaciones': 5.32691788627062e-41,
#  'esos': 1.4370208153710976e-28,
#  'presenta': 1.447847774253435e-26,
#  'dispararon': 0.0,
#  'confirmar': 1.7389639404588272e-202,
#  'eritrea': 0.0,
#  'implantarán': 0.0,
#  'encuadrada': 0.0,
#  'estímulo': 0.0,
#  'presentes': 3.119240538862698e-26,
#  'desembocaríamos': 0.0,
#  'lugares': 6.394122969373893e-75,
#  'invitar': 9.377094997179341e-28,
#  'constataremos': 0.0,
#  'septiembre': 1.570655883007964e-27,
#  'rentas': 0.0,
#  'hagan': 7.988550983215421e-23,
#  'profesor': 2.7118925841214008e-34,
#  'crítica': 1.0317671343622128e-22,
#  'especiales': 1.0114987785335823e-27,
#  'estrategia': 4.647747982413872e-25,
#  'enojada': 1.6338766938430558e-32,
#  'sereno': 1.972843584502765e-239,
#  'actúa': 0.0,
#  'testigos': 0.0,
#  'accesibilidad': 0.0,
#  'adoptadas': 9.139545892442179e-223,
#  'irreparables': 0.0,
#  'mantenernos': 0.0,
#  'así': 2.471440631973084e-06,
#  'abrigo': 1.5291996657176084e-22,
#  'jerárquica': 0.0,
#  'diferente': 0.0,
#  'comunitario': 2.1476328179608432e-23,
#  'grönitz': 3.096416986350284e-37,
#  'añadiendo': 0.0,
#  'inteligibilidad': 0.0,
#  'verdaderas': 2.2458386068375137e-95,
#  'complementaria': 1.0993443429684656e-30,
#  'incompatible': 0.0,
#  'aceptables': 2.857500498418793e-217,
#  'mínimas': 6.50892896477813e-26,
#  'reiteró': 0.0,
#  'institutos': 0.0,
#  'supongo': 4.5221840541590034e-20,
#  '0796': 0.0,
#  'obtiene': 0.0,
#  'operar': 0.0,
#  '299': 9.317440251953105e-221,
#  'tareas': 1.4409611769523043e-120,
#  'llegamos': 1.4917370686618678e-21,
#  'agrario': 0.0,
#  'tanto': 3.720098211944528e-10,
#  'navega': 0.0,
#  'apoye': 4.233409677469254e-22,
#  'segmento': 4.418152443434827e-61,
#  'reconoció': 0.0,
#  'siguiente': 3.011638777464333e-15,
#  'descubiertos': 0.0,
#  'debatida': 0.0,
#  'torno': 2.0608702101954602e-41,
#  'conteste': 5.503416396420159e-29,
#  'apoyados': 0.0,
#  'tranquilizar': 8.948477837115278e-34,
#  'disminución': 0.0,
#  'demostrarlo': 0.0,
#  'tecnológicos': 1.0435053097451676e-29,
#  '/': 2.1647518202367066e-21,
#  'decirles': 1.6202870063023933e-15,
#  'debatan': 6.207664505651428e-210,
#  'sinceridad': 1.0253341392173411e-35,
#  'marco': 3.8828834247914247e-16,
#  'serbias': 0.0,
#  'leyes': 8.230287727896513e-237,
#  'dejarla': 0.0,
#  'absolutamente': 5.788211172876583e-17,
#  'tomado': 7.120368650678533e-20,
#  'roissy': 6.0351610688061984e-33,
#  'sur': 1.4718066741955764e-36,
#  'necesaria': 2.2784002590347677e-17,
#  'disponible': 3.907857273610607e-234,
#  'discutible': 0.0,
#  'tax': 0.0,
#  'garantía': 0.0,
#  'desarrollos': 0.0,
#  '"¡': 0.0,
#  'placer': 4.19195655663573e-239,
#  'cascar': 4.547945724031001e-28,
#  'cee': 2.254937500203965e-141,
#  'sagradas': 0.0,
#  'procedencia': 0.0,
#  'ignorarlo': 0.0,
#  'yemení': 5.705499045861917e-62,
#  'interno': 1.9148813604905603e-25,
#  'intergubernamentales': 0.0,
#  'labor': 1.1054203996853499e-15,
#  'ricas': 1.474704351394304e-74,
#  'desconcentración': 2.167201597084632e-223,
#  'óptimas': 0.0,
#  'ajustadas': 0.0,
#  'sentasen': 0.0,
#  'efectiva': 8.64161371300527e-28,
#  'buscar': 0.0,
#  'recién': 0.0,
#  'sombrero': 9.734402870351504e-26,
#  'médicos': 7.343929285016007e-33,
#  'vigentes': 3.2724297383243152e-22,
#  'stop': 0.0,
#  'pilares': 2.973654299741114e-29,
#  'deberes': 0.0,
#  'valorando': 0.0,
#  'common': 1.06248264779149e-26,
#  'visita': 2.7892897004066572e-36,
#  'dependerá': 0.0,
#  'basado': 8.839049991117069e-224,
#  'remediando': 0.0,
#  'elige': 0.0,
#  'expire': 0.0,
#  'socios': 5.249306215884371e-26,
#  'contemplado': 1.2890784791091735e-214,
#  'solía': 0.0,
#  'candu': 0.0,
#  'destrucción': 0.0,
#  'unida': 0.0,
#  'agilización': 0.0,
#  'bloques': 0.0,
#  'llevada': 9.163835492562678e-31,
#  'otoño': 0.0,
#  'organizada': 0.0,
#  'impulsar': 6.738412446776208e-197,
#  'mencionando': 9.339009320899711e-32,
#  'fortalecerá': 0.0,
#  'cuxhaven': 0.0,
#  'melodías': 0.0,
#  'albanesa': 0.0,
#  'explorar': 0.0,
#  'boquerón': 8.124874795436811e-35,
#  'contraponer': 0.0,
#  'mantener': 4.188011756996103e-16,
#  'abusos': 5.782740271837957e-32,
#  'disminuya': 0.0,
#  'masiva': 0.0,
#  'intermedias': 0.0,
#  'insuficiencias': 6.193768123905283e-35,
#  'exámenes': 0.0,
#  'ratificar': 0.0,
#  'eje': 1.9364569146502097e-37,
#  'pedida': 0.0,
#  'hallaron': 0.0,
#  'prelación': 0.0,
#  'aguardo': 4.167014918426664e-27,
#  'hablaremos': 0.0,
#  'banqueros': 0.0,
#  'uniformes': 2.696638862134584e-30,
#  'toca': 0.0,
#  'consonancia': 0.0,
#  'religioso': 0.0,
#  'logro': 0.0,
#  'tratados': 3.5871172197645816e-24,
#  'teoría': 1.7911390635460185e-238,
#  'presentemos': 0.0,
#  'algún': 1.893129572535004e-21,
#  'destruyendo': 6.25730657108664e-239,
#  'utilizamos': 2.0989889927748824e-237,
#  'aplicarlos': 0.0,
#  'formar': 7.90591289671386e-34,
#  'justicia': 8.230813804935213e-18,
#  'regional': 1.911778930581713e-20,
#  'cuenten': 0.0,
#  'tiene': 1.8544662752680746e-13,
#  'ejercido': 0.0,
#  'fijado': 1.3118063050062038e-31,
#  'ultimando': 1.47036336638765e-25,
#  'arma': 0.0,
#  'turísticos': 0.0,
#  'rueda': 1.4789445332445329e-236,
#  'juicios': 0.0,
#  'escuelas': 0.0,
#  'pretensión': 1.5193087163688092e-38,
#  'constate': 0.0,
#  'peor': 7.907739204179853e-89,
#  'cauteloso': 0.0,
#  'allanen': 2.0585253125962626e-33,
#  'cuidadoso': 5.64364450439106e-16,
#  'acudían': 0.0,
#  'grave': 8.308026516609735e-28,
#  'citar': 3.4374968769203142e-28,
#  'salida': 0.0,
#  'evacuar': 0.0,
#  'ajustado': 0.0,
#  'haarder': 1.1829145959479316e-25,
#  'formentar': 1.3180457551731971e-28,
#  'piratas': 7.905901225728762e-247,
#  'encuentre': 9.80396246297323e-221,
#  'ejecutiva': 0.0,
#  'confianza': 1.1109604263519637e-20,
#  'antonieta': 0.0,
#  'dan': 2.2402753762214707e-233,
#  'turquía': 6.456287473410128e-26,
#  'diluye': 0.0,
#  'cálida': 0.0,
#  'pánico': 0.0,
#  'distintivos': 6.596909508065308e-239,
#  'estrechamente': 4.116161466946631e-189,
#  'correos': 0.0,
#  'ediciones': 1.6553771317132045e-30,
#  'profundización': 1.6765458043990036e-42,
#  'decepciones': 0.0,
#  'sensación': 4.332661776069263e-29,
#  'intentan': 0.0,
#  'notificación': 1.637964833858328e-251,
#  'ahí': 2.7942903274199605e-18,
#  'reproducidas': 1.0969929705543502e-25,
#  'transferir': 0.0,
#  'responderán': 0.0,
#  'señalar': 5.854118906225168e-12,
#  'dentro': 2.7580205482640243e-23,
#  'sustanciales': 0.0,
#  'hamburgo': 0.0,
#  'excluido': 1.3535701756361625e-31,
#  "'": 0.0,
#  'cúbicos': 0.0,
#  'lengua': 1.6021392072024204e-28,
#  'comenzar': 1.4868337144974656e-20,
#  'bendita': 1.9369255111386162e-24,
#  'demanda': 1.2096786420520401e-32,
#  'encargadas': 4.456798929898431e-28,
#  'categorías': 7.112018148472719e-32,
#  'significativa': 7.896895415212492e-23,
#  'acumulando': 0.0,
#  'reiterar': 1.90872092159799e-22,
#  'importa': 9.87419470907236e-93,
#  'violaciones': 0.0,
#  'stability': 0.0,
#  'fbi': 0.0,
#  'contestación': 3.654011263745927e-31,
#  'directores': 0.0,
#  'trabajemos': 0.0,
#  'petroleros': 1.2846846366908743e-41,
#  'parís': 2.9688685863912895e-57,
#  'demostramos': 0.0,
#  'satisfacción': 2.0714071247356885e-14,
#  'elaborado': 6.123071478375329e-19,
#  'abastecimiento': 0.0,
#  'aprovechando': 1.4792933892715537e-46,
#  'importen': 0.0,
#  'visibles': 0.0,
#  'necesitamos': 4.125633747968055e-21,
#  'incidente': 2.8937402495527513e-32,
#  'viernes': 2.880304604175266e-24,
#  'consultado': 2.2277369117223812e-164,
#  'felicitaciones': 1.2158014272463197e-35,
#  '86': 0.0,
#  'entrante': 1.442813026007875e-30,
#  'limitación': 2.1288416529277702e-38,
#  'aminorar': 0.0,
#  'mostrará': 0.0,
#  'culturas': 0.0,
#  'angular': 0.0,
#  '1917': 0.0,
#  'condolencia': 2.711961173903095e-29,
#  'enarbolen': 0.0,
#  'relativiza': 5.978953367776739e-34,
#  'cuidar': 0.0,
#  'alegrarían': 0.0,
#  'reembolsen': 0.0,
#  'burbujas': 0.0,
#  'hacías': 0.0,
#  'perplejidad': 0.0,
#  'suplementario': 0.0,
#  'ahora': 1.5397783136008454e-09,
#  'electrónica': 1.0804775065759905e-28,
#  '0028/96': 0.0,
#  'abra': 1.3161715143401944e-26,
#  'devuelta': 0.0,
#  'decirme': 3.2897906222356632e-43,
#  'mantenimiento': 8.896378602645295e-36,
#  'referéndum': 8.704522100461149e-31,
#  'incorporé': 2.5226372748296857e-31,
#  '6º': 9.470479956104087e-30,
#  'secular': 0.0,
#  'aplaza': 0.0,
#  'examinarán': 1.416490411955684e-30,
#  'severa': 0.0,
#  'entregan': 0.0,
#  'ankara': 0.0,
#  'demócratas': 1.2914234886533521e-24,
#  'calificativos': 1.4643018897202111e-40,
#  'lagunas': 6.437541248447142e-30,
#  'policéntrico': 0.0,
#  'cercano': 6.748375548839104e-210,
#  'sepa': 0.0,
#  'animar': 0.0,
#  'disertaciones': 0.0,
#  'diferentes': 2.8302424605016977e-21,
#  'inflexión': 1.0502908478427629e-35,
#  'dimes': 0.0,
#  'restablecimiento': 8.650982593413178e-36,
#  'popular': 3.481904853534461e-111,
#  'expectativas': 1.5810003056272014e-27,
#  'entregado': 0.0,
#  'alternativa': 0.0,
#  'intenta': 1.0228337273109217e-43,
#  'ordenador': 0.0,
#  'significaría': 0.0,
#  'turkmenistán': 0.0,
#  'soldados': 5.845268628821539e-37,
#  'impliquen': 0.0,
#  'enero': 1.5366155932031222e-29,
#  'resto': 3.302988875764291e-27,
#  'exención': 3.48405555460953e-26,
#  'evaluación': 3.925568967533168e-26,
#  'facilidades': 0.0,
#  'densa': 0.0,
#  'percepción': 0.0,
#  'observaron': 7.444254123188554e-141,
#  'legislatura': 2.9071080887597463e-29,
#  'recurramos': 0.0,
#  'interrupciones': 0.0,
#  'recoge': 2.790447214436463e-28,
#  'descuide': 0.0,
#  'volviendo': 2.3848372968042617e-30,
#  'hicieron': 9.618193456006127e-226,
#  'verse': 2.6031085676876133e-36,
#  'asesoramiento': 0.0,
#  'incrementa': 0.0,
#  'marea': 7.121469744770256e-33,
#  'dificulta': 0.0,
#  'goebbels': 9.421844609140665e-35,
#  'viii': 0.0,
#  'raíz': 2.3907815013630933e-127,
#  'conducirnos': 0.0,
#  'fraudes': 1.377079239971924e-29,
#  'reflexionar': 1.4977084148518412e-31,
#  'embriónico': 0.0,
#  'considerablemente': 6.989861559624583e-32,
#  'mayoría': 4.846667326458855e-25,
#  'reconocía': 0.0,
#  'realizar': 2.690049540291767e-20,
#  'elementos': 7.779030592974297e-25,
#  'abatirán': 0.0,
#  'revestirá': 4.788495782948324e-25,
#  'bloqueo': 0.0,
#  'relativo': 3.803721790564801e-14,
#  'proyecto': 1.2186144291627101e-21,
#  'despegue': 1.0872182921237742e-198,
#  'monetaria': 0.0,
#  'contará': 2.195082437302629e-48,
#  'adaptados': 0.0,
#  'socavar': 0.0,
#  'comenzaríamos': 0.0,
#  'sabios': 2.9309616790141507e-29,
#  'tarea': 1.0162899156703292e-17,
#  'contienen': 0.0,
#  'detallado': 5.016946066407838e-22,
#  'acordados': 0.0,
#  'devolver': 0.0,
#  'reconocemos': 1.3679600475935215e-46,
#  'basarse': 0.0,
#  'expresamos': 2.1781820693268279e-32,
#  'iban': 3.960508151567564e-228,
#  'perpetuamente': 0.0,
#  'intercultural': 0.0,
#  'malas': 2.5310279730091113e-178,
#  'conseguiremos': 7.942371085809963e-35,
#  'favorecido': 0.0,
#  'incrementar': 2.393607696365832e-121,
#  'típicamente': 0.0,
#  'corrientes': 3.6468428325700893e-221,
#  'expuso': 2.0826665560687753e-208,
#  'soberanía': 7.744475093976151e-234,
#  'adquiridas': 2.5402243554959407e-33,
#  'oídos': 0.0,
#  'reestructurarse': 0.0,
#  'teniendo': 5.617769812357142e-29,
#  'instalaciones': 0.0,
#  'barnhill': 5.165527584829132e-33,
#  'vínculos': 1.9078031439220597e-29,
#  'puñado': 0.0,
#  'abb': 1.1048363927879208e-45,
#  'viviendo': 0.0,
#  'bancario': 0.0,
#  'señale': 1.5861705639271972e-223,
#  'veinte': 0.0,
#  'considerado': 4.297891443491512e-30,
#  'conformes': 0.0,
#  'merma': 0.0,
#  'terceros': 0.0,
#  'incentivar': 0.0,
#  'hacerlos': 1.1234179838917725e-128,
#  'marchándose': 0.0,
#  'debidas': 0.0,
#  'acabamos': 1.1464275156599193e-26,
#  ...}

# %%
# Read Spanish dev sentences
with open('dev.es', 'r') as f:
    spanish_dev_corpus = f.readlines()
    spanish_dev_corpus = [i[:-1] for i in spanish_dev_corpus]
    spanish_dev_corpus = [i.split(' ') for i in spanish_dev_corpus]
    
# Read Spanish dev sentences
with open('dev.en', 'r') as f:
    english_dev_corpus = f.readlines()
    english_dev_corpus = [i[:-1] for i in english_dev_corpus]
    english_dev_corpus = [i.split(' ') for i in english_dev_corpus]

# %%
for i in range(len(english_dev_corpus)):
    english_dev_corpus[i] = ['NULL'] + english_dev_corpus[i]

# %%
# manipulate 'NULL' in t
for s_idx in tqdm(range(len(english_corpus))):
    for f_word in spanish_vocab:
        t['NULL'][f_word] = 0
        
for e_sent, f_sent in zip(english_dev_corpus, spanish_dev_corpus):
    m = len(f_sent)
    l = len(e_sent)
    for j, ew in enumerate(e_sent):
        for i, fw in enumerate(f_sent):
            if ew == 'NULL':
                q[l][m][(i,j)] = 0

# %%
result = []
for s_idx, sent in enumerate(spanish_dev_corpus):
    m = len(spanish_dev_corpus[s_idx])
    l = len(english_dev_corpus[s_idx])
    for fw_idx, f_word in enumerate(spanish_dev_corpus[s_idx]):
        best = 0
        index = 0
        for ew_idx, e_word in enumerate(english_dev_corpus[s_idx]):
            if q[l][m][(fw_idx, ew_idx)]*t[e_word][f_word] > best:
                best = q[l][m][(fw_idx, ew_idx)]*t[e_word][f_word]
                index = ew_idx
                
        result.append(str(s_idx+1)+" "+str(index+1)+" "+str(fw_idx+1))

# %%
with open('dev_result2.key', 'w') as f:
    for item in result:
        f.write("%s\n" % item)

# %%
# !python3 eval_alignment.py dev.key dev_result2.key
# Out:
#       Type       Total   Precision      Recall     F1-Score
# ===============================================================
#      total        5920     0.025        0.026        0.026
